# %% [markdown]
# # MLB Pitch Data
#
# https://www.kaggle.com/pschale/mlb-pitch-data-20152018/home

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
atbats = pd.read_csv('../../datasets/mlb/atbats.csv', sep=',')
atbats.count()
# Out:
# ab_id         740389
# batter_id     740389
# event         740389
# g_id          740389
# inning        740389
# o             740389
# p_score       740389
# p_throws      740389
# pitcher_id    740389
# stand         740389
# top           740389
# dtype: int64

# %%
atbats.head()
# Out:
#         ab_id  batter_id      event       g_id  inning  o  p_score p_throws  \
# 0  2015000001     572761  Groundout  201500001       1  1        0        L
# 1  2015000002     518792     Double  201500001       1  1        0        L
# 2  2015000003     407812     Single  201500001       1  1        0        L
# 3  2015000004     425509  Strikeout  201500001       1  2        0        L
# 4  2015000005     571431  Strikeout  201500001       1  3        0        L
#
#    pitcher_id stand   top
# 0      452657     L  True
# 1      452657     L  True
# 2      452657     R  True
# 3      452657     R  True
# 4      452657     L  True

# %%
games = pd.read_csv('../../datasets/mlb/games.csv', sep=',')
games.count()
# Out:
# g_id                9718
# attendance          9718
# away_final_score    9718
# away_team           9718
# date                9718
# elapsed_time        9718
# home_final_score    9718
# home_team           9718
# start_time          9718
# umpire_1B           9718
# umpire_2B           9715
# umpire_3B           9718
# umpire_HP           9718
# venue_name          9718
# weather             9718
# wind                9718
# delay                506
# dtype: int64

# %%
games.head()
# Out:
#         g_id attendance  away_final_score away_team        date elapsed_time  \
# 0  201500001     35,055                 3       sln  2015-04-05         3:04
# 1  201500002     45,909                 1       ana  2015-04-06         2:33
# 2  201500003     36,969                 2       atl  2015-04-06         2:36
# 3  201500004     31,042                 6       bal  2015-04-06         3:01
# 4  201500005     45,549                 8       bos  2015-04-06         3:01
#
#    home_final_score home_team start_time    umpire_1B       umpire_2B  \
# 0                 0       chn    7:17 PM  Mark Wegner    Marty Foster
# 1                 4       sea    1:12 PM    Ron Kulpa    Brian Knight
# 2                 1       mia    4:22 PM     Laz Diaz  Chris Guccione
# 3                 2       tba    3:12 PM    Ed Hickox     Paul Nauert
# 4                 0       phi    3:08 PM   Phil Cuzzi   Tony Randazzo
#
#          umpire_3B      umpire_HP          venue_name  \
# ...

# %%
pitches = pd.read_csv('../../datasets/mlb/pitches.csv', sep=',')
pitches.count()/1e6
# Out:
# ab_id              2.867162
# ax                 2.852973
# ay                 2.852973
# az                 2.852973
# b_count            2.867162
# b_score            2.867162
# break_angle        2.852973
# break_length       2.852973
# break_y            2.852973
# code               2.854505
# end_speed          2.853048
# nasty              2.852973
# on_1b              2.867162
# on_2b              2.867162
# on_3b              2.867162
# outs               2.867162
# pfx_x              2.853020
# pfx_z              2.853020
# pitch_num          2.867162
# pitch_type         2.852973
# px                 2.852973
# pz                 2.852973
# s_count            2.867162
# spin_dir           2.852973
# spin_rate          2.852973
# start_speed        2.853048
# sz_bot             2.865079
# sz_top             2.865079
# type               2.867162
# type_confidence    2.852973
# vx0                2.852973
# vy0                2.852973
# vz0                2.852973
# ...

# %%
pitches.head(20)
# Out:
#            ab_id      ax      ay      az  b_count  b_score  break_angle  \
# 0   2.015000e+09   7.665  34.685 -11.960        0        0        -25.0
# 1   2.015000e+09  12.043  34.225 -10.085        0        0        -40.7
# 2   2.015000e+09  14.368  35.276 -11.560        0        0        -43.7
# 3   2.015000e+09   2.104  28.354 -20.540        0        0         -1.3
# 4   2.015000e+09 -10.280  21.774 -34.111        1        0         18.4
# 5   2.015000e+09  13.590  32.274 -10.333        2        0        -45.7
# 6   2.015000e+09  14.549  31.469  -9.734        0        0        -46.3
# 7   2.015000e+09  -1.339  27.421 -19.326        1        0          7.3
# 8   2.015000e+09  13.808  28.169 -11.591        0        0        -45.0
# 9   2.015000e+09   1.218  28.828 -19.782        1        0          2.0
# 10  2.015000e+09  15.709  32.602 -15.243        2        0        -39.0
# 11  2.015000e+09  17.411  26.452 -22.438        0        1        -34.4
# ...

# %%
player_names = pd.read_csv('../../datasets/mlb/player_names.csv', sep=',')
player_names.count()
# Out:
# id            2218
# first_name    2218
# last_name     2218
# dtype: int64

# %%
player_names.head()
# Out:
#        id first_name   last_name
# 0  452657        Jon      Lester
# 1  425794       Adam  Wainwright
# 2  457435       Phil        Coke
# 3  435400      Jason       Motte
# 4  519166       Neil     Ramirez

# %%
player_names['id' == 572761]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-deb89459e9f0> in <module>
# ----> 1 player_names['id' == 572761]
#
# ...
